# %%
#Importing librairies
import matplotlib.pyplot as plt

import numpy   as np
import sklearn as sk
import nibabel as nb
import scipy   as sp
import csv
import os

from nilearn import datasets, input_data

# %%
dPath = os.getcwd() + '/data/'

X = np.load(dPath + 'data_X.npy').astype('float32')
Y = np.load(dPath + 'data_xyz.npy').astype('float32')

# %% [markdown]
# # Neural Networks

# %%
#Importing
from keras.models        import Sequential
from keras.layers        import Dense, Dropout, LSTM
from keras.optimizers    import SGD, RMSprop
from keras.preprocessing import sequence
from keras.utils         import np_utils

from keras.datasets import mnist
# Out:
# Using TensorFlow backend.

# %%
import numpy
from keras.datasets import imdb
from keras.models import Sequential
from keras.layers import Dense
from keras.layers import LSTM
from keras.layers.embeddings import Embedding
from keras.preprocessing import sequence
# fix random seed for reproducibility
numpy.random.seed(7)
# Out:
# Using TensorFlow backend.

# %%
def buildModel(P):
    '''P is a dictionnary of parameters'''
    
    #Distance Matrix size
    DmatrixSize = P['Ntr']**2/2 - P['Ntr']
    
    #Feedforward
    model = Sequential()  
    
    #LSTM Layer
    model.add(LSTM(P['Ntr'], input_shape = (P['LSTMsize'],1)))  
    
    #Output layer
    model.add(Dense(P['LSTMsize'], DmatrixSize))
    
    model.add(Activation("linear"))  
    
    #Training
    model.compile(loss="mean_squared_error", optimizer="rmsprop") 
    
    print(model.summary())

# %%
#def trainModel(model, P, X, Y):
    '''
    Model is the model
    P is a parameter dictionnary
    D is your data matrix (Containing X and Y)
    '''
    
for i in range(P['nIters']):

    #Training sample
    permIdx        = np.random.permutation(P['N'])

    #Training X and Y
    Xtrain = X[ permIdx[:P['Ntr'] ] , :P['Ttr']].T
    Ytrain = sp.spatial.distance.pdist( Y[ permIdx[:P['Ntr']], : ], 'euclidean')

    #Training example
    Xtrain = Xtrain/abs(Xtrain.max())

    #Training
    model.fit(Xtrain, Ytrain, nIters = P['nIters'], batch_size = 1, verbose=2)

        #return model

# %%
#Initializing parameter dictionnary
P = {}

#Parameters
P['N']    = X.shape[0]
P['T']    = X.shape[1]
P['Ttr']  = 100
P['Ntr']  = 10000
P['LSTMsize'] = 12000
P['nIters']   = 100

#Building and training
M = buildModel(P)
#M = trainModel(M,P,X,Y)

# %%
# Create the model
model = Sequential()
model.add(Embedding(top_words, embedding_vecor_length, input_length=max_review_length))
model.add(LSTM(100))
model.add(Dense(1, activation='sigmoid'))
model.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy'])
print(model.summary())
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-29-8a0bb25f9069> in <module>()
#       1 # Create the model
#       2 model = Sequential()
# ----> 3 model.add(Embedding(top_words, embedding_vecor_length, input_length=max_review_length))
#       4 model.add(LSTM(100))
#       5 model.add(Dense(1, activation='sigmoid'))
#
# NameError: name 'embedding_vecor_length' is not defined

# %%
model.fit(X_train, y_train, validation_data=(X_test, y_test), nb_epoch=1, batch_size=64)
# Out:
# Train on 25000 samples, validate on 25000 samples
# Epoch 1/1
# 25000/25000 [==============================] - 781s - loss: 0.5965 - acc: 0.6880 - val_loss: 0.5969 - val_acc: 0.7098

# %%
# load the dataset but only keep the top n words, zero the rest
top_words = 5000
(X_train, y_train), (X_test, y_test) = imdb.load_data(nb_words=top_words)

# load the dataset but only keep the top n words, zero the rest
top_words = 5000
(X_train, y_train), (X_test, y_test) = imdb.load_data(nb_words=top_words)

# truncate and pad input sequences
max_review_length = 500
X_train = sequence.pad_sequences(X_train, maxlen=max_review_length)
X_test = sequence.pad_sequences(X_test, maxlen=max_review_length)

# %%
# Final evaluation of the model
scores = model.evaluate(X_test, y_test, verbose=0)
print("Accuracy: %.2f%%" % (scores[1]*100))

# Final evaluation of the model
scores = model.evaluate(X_test, y_test, verbose=0)
print("Accuracy: %.2f%%" % (scores[1]*100))
# Out:
# Accuracy: 70.98%
# Accuracy: 70.98%
